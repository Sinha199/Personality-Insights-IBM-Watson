# %% [markdown]
# # This notebook shows the Personality Insights service with IBM Watson

# %% [markdown]
# ### Set up the Personality Insights Service on IBM cloud.

# %%
#Install the ibm watson to deploy the services. 

# !pip install "ibm-watson>=4.3.0"

# %%
#install the wget module 
# !pip install wget
# Out:
# ...
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# ...

# %% [markdown]
# ### Download the wget module to download the profile.json file

# %%
import wget
url='https://watson-developer-cloud.github.io/doc-tutorial-downloads/personality-insights/reference/profile.json'
wget.download(url)
# Out:
# 'profile (10).json'

# %% [markdown]
# ## Add the apikey and url from the credentials of the service created on the IBM cloud

# %%
from ibm_watson import PersonalityInsightsV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('ohCiTamS6_lh9crfmXw_qbHeVJHlScuyXD_p_aE3lIFZ')
personality_insights = PersonalityInsightsV3(
    version='{version}',
    authenticator=authenticator
)

personality_insights.set_service_url('https://api.us-south.personality-insights.watson.cloud.ibm.com/instances/148952f9-9429-4db0-a1c2-1cb3d9250401')

# %% [markdown]
# ## Setting the default header

# %%
personality_insights.set_default_headers({'x-watson-learning-opt-out': "true"})

# %% [markdown]
# ## Opening the insights infered from the data stored in the profile.json file from various twitter comments by launguage analysis.

# %%
from ibm_watson import PersonalityInsightsV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from os.path import join, dirname
import json

authenticator = IAMAuthenticator('ohCiTamS6_lh9crfmXw_qbHeVJHlScuyXD_p_aE3lIFZ')
personality_insights = PersonalityInsightsV3(
    version='2017-10-13',
    authenticator=authenticator
)

personality_insights.set_service_url('https://api.us-south.personality-insights.watson.cloud.ibm.com/instances/148952f9-9429-4db0-a1c2-1cb3d9250401')

with open(join(dirname('__file__'), './profile.json')) as profile_json:
    profile = personality_insights.profile(
        profile_json.read(),
        'application/json',
        content_type='application/json',
        consumption_preferences=True,
        raw_scores=True
    ).get_result()
print(json.dumps(profile, indent=2))
# Out:
# {
#   "word_count": 15223,
#   "processed_language": "en",
#   "personality": [
#     {
#       "trait_id": "big5_openness",
#       "name": "Openness",
#       "category": "personality",
#       "percentile": 0.8011555009552995,
#       "raw_score": 0.7756540425503807,
#       "significant": true,
#       "children": [
#         {
#           "trait_id": "facet_adventurousness",
#           "name": "Adventurousness",
#           "category": "personality",
#           "percentile": 0.8975586904731845,
#           "raw_score": 0.5499070403121895,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_artistic_interests",
#           "name": "Artistic interests",
#           "category": "personality",
#           "percentile": 0.9770309419531928,
#           "raw_score": 0.7663670485959848,
#           "significant": true
#         },
#         {
#           "trait_id": "facet_emotionality",
#           "name": "Emotionality",
# ...

# %% [markdown]
# ## Summary
# ### The output of above cell shows the trait of individual objects.
